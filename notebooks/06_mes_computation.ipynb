# %% [markdown]
# # MES Computation
#
# Combine the four sub-indices into the composite MES and flag mobility
# deserts. Produces the per-city MES GeoJSONs.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))  # project root on path
from src.processing.build_subindices import main as build_subs
from src.processing.build_mes import main as build_mes
build_subs()
build_mes()

# %%
import geopandas as gpd
gdf = gpd.read_file('../data/processed/mes_scores/chicago_mes.geojson')
gdf[['MES','mobility_desert','compounded_desert']].describe(include='all')
