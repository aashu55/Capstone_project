# %% [markdown]
# # Dashboard Prototyping
#
# Prototype the dashboard figures. Launch the full app with
# `python -m src.dashboard.app`.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))  # project root on path
from src.dashboard.utils import load_city, choropleth, equity_gap_figure, ranked_table
gdf = load_city('seattle')
choropleth(gdf, 'MES')

# %%
ranked_table(gdf, 'MES').head(10)

# %%
equity_gap_figure(['chicago','houston','seattle'])
